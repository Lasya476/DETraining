# %%
#1. Loading the Data and displaying first 5 rows

import pandas as pd
import statistics

df = pd.read_csv('/Users/lasya/Downloads/Crime_Data_from_2020_to_Present.csv')

# %%
df.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7
# 1  200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
# 2  200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700     3
# 3  200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037     9
# 4  220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200     6
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0   Wilshire          784         1     510
# 1    Central          182         1     330
# 2  Southwest          356         1     480
# 3   Van Nuys          964         1     343
# 4  Hollywood          666         2     354
#
#                                 Crm Cd Desc  ... Status   Status Desc  \
# 0                          VEHICLE - STOLEN  ...     AA  Adult Arrest
# 1                     BURGLARY FROM VEHICLE  ...     IC   Invest Cont
# ...

# %%
#Column Names
df.columns
# Out:
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
#        'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
#        'LON'],
#       dtype='object')

# %%
#Number of rows and columns 

print("Number of Rows:",len(df))
print("Number of Columns:",len(df.columns))
# Out:
# Number of Rows: 982638
# Number of Columns: 28

# %%
df.describe
# Out:
# <bound method NDFrame.describe of             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0       190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130
# 1       200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800
# 2       200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700
# 3       200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037
# 4       220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200
# ...           ...                     ...                     ...       ...
# 982633  242011172  08/20/2024 12:00:00 AM  08/17/2024 12:00:00 AM      2300
# 982634  240710284  07/24/2024 12:00:00 AM  07/23/2024 12:00:00 AM      1400
# 982635  240104953  01/15/2024 12:00:00 AM  01/15/2024 12:00:00 AM       100
# 982636  240309674  04/24/2024 12:00:00 AM  04/24/2024 12:00:00 AM      1500
# 982637  240910892  08/13/2024 12:00:00 AM  08/12/2024 12:00:00 AM      2300
#
# ...

# %%
# Minimum, max and median age of victims 
print("Minimum Age of a Victim:", min(df['Vict Age']))
# Out:
# Minimum Age of a Victim: -4

# %%
print("Maximum Age of a Victim:", max(df['Vict Age']))
# Out:
# Maximum Age of a Victim: 120

# %%
print("Median Age of a Victim:", statistics.median(df['Vict Age']))
# Out:
# Median Age of a Victim: 30.0

# %%
df.dtypes
# Out:
# DR_NO               int64
# Date Rptd          object
# DATE OCC           object
# TIME OCC            int64
# AREA                int64
# AREA NAME          object
# Rpt Dist No         int64
# Part 1-2            int64
# Crm Cd              int64
# Crm Cd Desc        object
# Mocodes            object
# Vict Age            int64
# Vict Sex           object
# Vict Descent       object
# Premis Cd         float64
# Premis Desc        object
# Weapon Used Cd    float64
# Weapon Desc        object
# Status             object
# Status Desc        object
# Crm Cd 1          float64
# Crm Cd 2          float64
# Crm Cd 3          float64
# Crm Cd 4          float64
# LOCATION           object
# Cross Street       object
# LAT               float64
# LON               float64
# dtype: object

# %%
#3. Adding and Modifying Columns 

df['DATE OCC'] = pd.to_datetime(df['DATE OCC'])

# %%
df['DayOfWeek'] = df['DATE OCC'].dt.day_name()
print(df)
# Out:
#             DR_NO               Date Rptd   DATE OCC  TIME OCC  AREA  \
# 0       190326475  03/01/2020 12:00:00 AM 2020-03-01      2130     7
# 1       200106753  02/09/2020 12:00:00 AM 2020-02-08      1800     1
# 2       200320258  11/11/2020 12:00:00 AM 2020-11-04      1700     3
# 3       200907217  05/10/2023 12:00:00 AM 2020-03-10      2037     9
# 4       220614831  08/18/2022 12:00:00 AM 2020-08-17      1200     6
# ...           ...                     ...        ...       ...   ...
# 982633  242011172  08/20/2024 12:00:00 AM 2024-08-17      2300    20
# 982634  240710284  07/24/2024 12:00:00 AM 2024-07-23      1400     7
# 982635  240104953  01/15/2024 12:00:00 AM 2024-01-15       100     1
# 982636  240309674  04/24/2024 12:00:00 AM 2024-04-24      1500     3
# 982637  240910892  08/13/2024 12:00:00 AM 2024-08-12      2300     9
#
#         AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0        Wilshire          784         1     510
# ...

# %%
df = df.drop(columns=['DayofWeek'])

# %%
print(df.columns)
# Out:
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
#        'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
#        'LON', 'DayOfWeek'],
#       dtype='object')

# %%
print(df)
# Out:
#             DR_NO               Date Rptd   DATE OCC  TIME OCC  AREA  \
# 0       190326475  03/01/2020 12:00:00 AM 2020-03-01      2130     7
# 1       200106753  02/09/2020 12:00:00 AM 2020-02-08      1800     1
# 2       200320258  11/11/2020 12:00:00 AM 2020-11-04      1700     3
# 3       200907217  05/10/2023 12:00:00 AM 2020-03-10      2037     9
# 4       220614831  08/18/2022 12:00:00 AM 2020-08-17      1200     6
# ...           ...                     ...        ...       ...   ...
# 982633  242011172  08/20/2024 12:00:00 AM 2024-08-17      2300    20
# 982634  240710284  07/24/2024 12:00:00 AM 2024-07-23      1400     7
# 982635  240104953  01/15/2024 12:00:00 AM 2024-01-15       100     1
# 982636  240309674  04/24/2024 12:00:00 AM 2024-04-24      1500     3
# 982637  240910892  08/13/2024 12:00:00 AM 2024-08-12      2300     9
#
#         AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0        Wilshire          784         1     510
# ...

# %%
crimes_by_day = df.groupby('DayOfWeek').size().reset_index(name='CrimeCount')
print(crimes_by_day)
# Out:
#    DayOfWeek  CrimeCount
# 0     Friday      150192
# 1     Monday      138516
# 2   Saturday      144106
# 3     Sunday      136586
# 4   Thursday      138622
# 5    Tuesday      134947
# 6  Wednesday      139669

# %%
sorted_crimes = crimes_by_day.sort_values(by='CrimeCount', ascending=False)

day_with_most_crimes = sorted_crimes.iloc[0]


print(day_with_most_crimes)
# Out:
# DayOfWeek     Friday
# CrimeCount    150192
# Name: 0, dtype: object

# %%
df_filtered = df[df['Crm Cd Desc'] == "THEFT"] 

print(df_filtered)
# Out:
#             DR_NO               Date Rptd   DATE OCC  TIME OCC  AREA  \
# 0       190326475  03/01/2020 12:00:00 AM 2020-03-01      2130     7
# 1       200106753  02/09/2020 12:00:00 AM 2020-02-08      1800     1
# 2       200320258  11/11/2020 12:00:00 AM 2020-11-04      1700     3
# 3       200907217  05/10/2023 12:00:00 AM 2020-03-10      2037     9
# 4       220614831  08/18/2022 12:00:00 AM 2020-08-17      1200     6
# ...           ...                     ...        ...       ...   ...
# 982633  242011172  08/20/2024 12:00:00 AM 2024-08-17      2300    20
# 982634  240710284  07/24/2024 12:00:00 AM 2024-07-23      1400     7
# 982635  240104953  01/15/2024 12:00:00 AM 2024-01-15       100     1
# 982636  240309674  04/24/2024 12:00:00 AM 2024-04-24      1500     3
# 982637  240910892  08/13/2024 12:00:00 AM 2024-08-12      2300     9
#
#         AREA NAME  Rpt Dist No  Part 1-2  Crm Cd Crm Cd Desc  ...  \
# 0        Wilshire          784         1     510       THEFT  ...
# ...

# %%
df_filtered.to_csv("central_area_thefts.csv", index=False)
